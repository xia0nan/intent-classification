# %% [markdown]
# ## Import

# %%
import re
import math
import string
import time

import numpy as np
import pandas as pd

import string
import pickle

from scipy.sparse import hstack

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics.pairwise import cosine_distances

import spacy
from spacy.lang.en.stop_words import STOP_WORDS

import gensim.downloader as api

from nltk.tokenize import word_tokenize

# %% [markdown]
# ## Load

# %%
# !wget -P "temp" -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
# Out:
# --2020-04-21 02:55:32--  https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.89.222
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.89.222|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647046227 (1.5G) [application/x-gzip]
# Saving to: ‘temp/GoogleNews-vectors-negative300.bin.gz’
#
# GoogleNews-vectors- 100%[===================>]   1.53G  6.37MB/s    in 4m 10s
#
# 2020-04-21 02:59:43 (6.29 MB/s) - ‘temp/GoogleNews-vectors-negative300.bin.gz’ saved [1647046227/1647046227]

# %%
# %%time
# from gensim.models import KeyedVectors
# EMBEDDING_FILE = 'temp/GoogleNews-vectors-negative300.bin.gz'
# word2vec = KeyedVectors.load_word2vec_format(EMBEDDING_FILE, binary=True)

# %%
# list of punctuation marks
punctuations = string.punctuation

# Create spacy word2vec and list of stopwords
nlp = spacy.load('en_core_web_sm')
stop_words = spacy.lang.en.stop_words.STOP_WORDS

# load classifier
with open("temp/RFClassifier2.pkl", 'rb') as f:
    clf2 = pickle.load(f)

# load vectorizer
with open('temp/TFIDFVectorizer_lemma2.pkl', 'rb') as f:
    v_lemma2 = pickle.load(f)
with open('temp/TFIDFVectorizer_keyword2.pkl', 'rb') as f:
    v_keyword2 = pickle.load(f)
with open('temp/TFIDFVectorizer_noun2.pkl', 'rb') as f:
    v_noun2 = pickle.load(f)
with open('temp/TFIDFVectorizer_verb2.pkl', 'rb') as f:
    v_verb2 = pickle.load(f)

# load intent2index
with open('temp/intent2index2.pkl', 'rb') as f:
    intent2index2 = pickle.load(f)
    
# load keyword_list_lemma
with open('temp/keyword_list_lemma2.pkl', 'rb') as f:
    keyword_list_lemma2 = pickle.load(f)

# load word2vec
try:
    word2vec
except NameError:
    word2vec = api.load("word2vec-google-news-300")

# %% [markdown]
# ## Utilities

# %%
# utilities
def get_nlp_features(df, keyword_list_lemma):
    """ Get keyword features from dataframe """
    data = df.copy()
    data['lemma'] = data['query'].apply(lambda x:' '.join([token.lemma_ for token in nlp(x) if token.lemma_ not in stop_words]))
    data['keyword'] = data['lemma'].apply(lambda x: list(set([token.lemma_ for token in nlp(x) if token.lemma_ in keyword_list_lemma])))

    data['noun'] = data['query'].apply(lambda x: list(set([token.lemma_ for token in nlp(x) if token.pos_ in ['NOUN','PROPN'] and token.lemma_ not in stop_words])))
    data['verb'] = data['query'].apply(lambda x: list(set([token.lemma_ for token in nlp(x) if token.pos_ in ['VERB'] and token.lemma_ not in stop_words])))

    data['noun'] = data['noun'].apply(lambda x: ' '.join([w for w in x]))
    data['verb'] = data['verb'].apply(lambda x: ' '.join([w for w in x]))
    data['keyword'] = data['keyword'].apply(lambda x: ' '.join([w for w in x]))
    return data

def clean_text(text):
    """ Basic text cleaning
        
        1. lowercase
        2. remove special characters
    """
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    return text

def nltk_tokenize(text):
    """ tokenize text using NLTK and join back as sentence"""
    # import nltk
    # nltk.download('punkt')
    return ' '.join(word_tokenize(text))

def add_nlp_vec_alone(df, v_lemma, v_keyword, v_noun, v_verb):
    """ Transform NLP features to vector for input X using TFIDF """
    x_test_lemma = v_lemma.transform(df['lemma'])
    x_test_keyword = v_keyword.transform(df['keyword'])
    x_test_noun = v_noun.transform(df['noun'])
    x_test_verb = v_verb.transform(df['verb'])
    
    # combine all features 
    x_test_combined = hstack((x_test_lemma,
                              x_test_keyword,
                              x_test_noun,
                              x_test_verb),format='csr')

    x_test_combined_columns = v_lemma.get_feature_names()+\
                              v_keyword.get_feature_names()+\
                              v_noun.get_feature_names()+\
                              v_verb.get_feature_names()
    
    x_test_combined = pd.DataFrame(x_test_combined.toarray())
    x_test_combined.columns = x_test_combined_columns
    
    return x_test_combined

def get_target_name(index, index2intent):
    return index2intent[index]

# %% [markdown]
# ## Run

# %%
def get_intent_nlp(query):
    """ 
        return a dataframe df
        columns: pred_seq, intent_class, intent_string, pred_prob
        rows: top 3 prediciton, example for first row: 1, 0, Promotions, 0.66
    """

    start = time.time()

    #%% pipeline
    # convert question to dataframe
    df = pd.DataFrame()
    df = pd.DataFrame(columns=['query'])
    df.loc[0] = [query]
    
    print("Part1", time.time() - start)

    # preprocessing test query
    df['query'] = df['query'].apply(clean_text)
    df['query'] = df['query'].apply(nltk_tokenize)
    df['query'] = df['query'].apply(lambda x:' '.join([token.lemma_ for token in nlp(x) if token.lemma_ not in stop_words]))
    df['query'] = df['query'].str.lower()
    
    print("Part2", time.time() - start)

    # get nlp features
    df = get_nlp_features(df, keyword_list_lemma2)
    
    print("Part3", time.time() - start)
    
    X_in = add_nlp_vec_alone(df, v_lemma2, v_keyword2, v_noun2, v_verb2)
    
    print("Part4", time.time() - start)

    # get prediction proba, use another classifier
    # TODO: train classifier 2
    probs = clf2.predict_proba(X_in)
    
    print("Part5", time.time() - start)

    # get index for top 3 prediction by proba
    ind = np.argsort(probs, axis=1)[:,-3:]

    # save probability
    proba = probs[0][ind[0]]
    
    print("Part6", time.time() - start)

    # save predicitons as dataframe
    best_3 = pd.DataFrame(ind,columns=['top3','top2','top1'])
    best_3['top1'] = clf.classes_[best_3['top1']]
    best_3['top2'] = clf.classes_[best_3['top2']]
    best_3['top3'] = clf.classes_[best_3['top3']]
    best_3['top3_prob'] = proba[0]
    best_3['top2_prob'] = proba[1]
    best_3['top1_prob'] = proba[2]
    
    print("Part7", time.time() - start)

    # get index to intent dictionary from intent2index
    index2intent = {y:x for x,y in intent2index2.items()}

    # get class name of top predictions
    best_3['top1_name'] = best_3['top1'].apply(get_target_name, index2intent=index2intent)
    best_3['top2_name'] = best_3['top2'].apply(get_target_name, index2intent=index2intent)
    best_3['top3_name'] = best_3['top3'].apply(get_target_name, index2intent=index2intent)
    
    print("Part8", time.time() - start)

    # output prediction
    top1 = best_3.at[0,'top1_name']
    top2 = best_3.at[0,'top2_name']
    top3 = best_3.at[0,'top3_name']
    top1_prob = best_3.at[0,'top1_prob']
    top2_prob = best_3.at[0,'top2_prob']
    top3_prob = best_3.at[0,'top3_prob']
    
    print("Part9", time.time() - start)

#     print(f'For sentence:\n{query}\n')
#     print(f'Top 1 prediction intent is {top1} with probability {100*top1_prob:.2f}%')
#     print(f'Top 2 prediction intent is {top2} with probability {100*top2_prob:.2f}%')
#     print(f'Top 3 prediction intent is {top3} with probability {100*top3_prob:.2f}%')

    top1_class = best_3.at[0,'top1']
    top2_class = best_3.at[0,'top2']
    top3_class = best_3.at[0,'top3']

    # convert to output
    df = pd.DataFrame([
            [1, top1_class, top1, top1_prob],
            [2, top2_class, top2, top2_prob],
            [3, top3_class, top3, top3_prob]
        ], columns=['pred_seq', 'intent_class', 'intent', 'pred_prob'])
    
    print("Part10", time.time() - start)

    inference_time = time.time() - start
    return df, inference_time

# %%
test_query = "Please show me the current promotions"

# %%
get_intent_nlp(test_query)
# Out:
# Part1 0.007563114166259766
# Part2 0.022623538970947266
# Part3 0.05807757377624512
# Part4 0.06486225128173828
# Part5 0.17626595497131348
# Part6 0.1767432689666748
# Part7 0.18040680885314941
# Part8 0.18406200408935547
# Part9 0.18462753295898438
# Part10 0.18629121780395508
# (   pred_seq  intent_class             intent  pred_prob
#  0         1            45         Promotions   0.980395
#  1         2            46    Card Promotions   0.015000
#  2         3            26  Give a compliment   0.002132,
#  0.18636584281921387)

# %%
import cProfile
cProfile.run('get_intent_nlp(test_query)')
# Out:
# For sentence:
# Please show me the current promotions
#
# Top 1 prediction intent is Promotions with probability 98.04%
# Top 2 prediction intent is Card Promotions with probability 1.50%
# Top 3 prediction intent is Give a compliment with probability 0.21%
#          197789 function calls (196781 primitive calls) in 0.500 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(amax)
#        22    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(append)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(argsort)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#        46    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_1d)
#        30    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_2d)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(bincount)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(broadcast_to)
#        98    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(can_cast)
#       145    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(concatenate)
#        28    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#        18    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(cumsum)
#        15    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(empty_like)
#        45    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(hstack)
#        26    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(nonzero)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#        30    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(ravel)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#         9    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(sum)
#        15    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(unique)
#        10    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(vstack)
#      1018    0.002    0.000    0.003    0.000 <frozen importlib._bootstrap>:416(parent)
#      1332    0.003    0.000    0.006    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:11(<lambda>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:11(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:12(<lambda>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:12(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:13(<lambda>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:13(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:16(clean_text)
#         1    0.000    0.000    0.073    0.073 <ipython-input-3-c44216b7ca35>:2(get_nlp_features)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:26(nltk_tokenize)
#         1    0.000    0.000    0.015    0.015 <ipython-input-3-c44216b7ca35>:32(add_nlp_vec_alone)
#         1    0.000    0.000    0.013    0.013 <ipython-input-3-c44216b7ca35>:5(<lambda>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:5(<listcomp>)
#         3    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:55(get_target_name)
#         1    0.000    0.000    0.013    0.013 <ipython-input-3-c44216b7ca35>:6(<lambda>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:6(<listcomp>)
#         1    0.000    0.000    0.013    0.013 <ipython-input-3-c44216b7ca35>:8(<lambda>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:8(<listcomp>)
#         1    0.000    0.000    0.013    0.013 <ipython-input-3-c44216b7ca35>:9(<lambda>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-3-c44216b7ca35>:9(<listcomp>)
#         1    0.000    0.000    0.500    0.500 <ipython-input-8-960b898c421c>:1(get_intent_nlp)
#         1    0.000    0.000    0.015    0.015 <ipython-input-8-960b898c421c>:19(<lambda>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-8-960b898c421c>:19(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-8-960b898c421c>:47(<dictcomp>)
#         1    0.000    0.000    0.500    0.500 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:129(word_tokenize)
#         1    0.000    0.000    0.000    0.000 __init__.py:146(<listcomp>)
#         5    0.000    0.000    0.000    0.000 __init__.py:19(_return_en)
#         1    0.000    0.000    0.000    0.000 __init__.py:95(sent_tokenize)
#        90    0.000    0.000    0.001    0.000 _asarray.py:141(ascontiguousarray)
#   405/387    0.001    0.000    0.002    0.000 _asarray.py:16(asarray)
#         6    0.000    0.000    0.000    0.000 _asarray.py:223(require)
#         6    0.000    0.000    0.000    0.000 _asarray.py:300(<setcomp>)
#       458    0.001    0.000    0.001    0.000 _asarray.py:88(asanyarray)
#         1    0.000    0.000    0.000    0.000 _base.py:172(_partition_estimators)
#      1001    0.002    0.000    0.007    0.000 _classes.py:377(_validate_X_predict)
#      1000    0.018    0.000    0.105    0.000 _classes.py:880(predict_proba)
#         9    0.000    0.000    0.000    0.000 _config.py:13(get_config)
#         4    0.000    0.000    0.001    0.000 _data.py:1644(normalize)
#         1    0.000    0.000    0.001    0.001 _decorators.py:225(wrapper)
#       101    0.000    0.000    0.000    0.000 _dtype.py:319(_name_includes_bit_suffix)
#       101    0.001    0.000    0.001    0.000 _dtype.py:333(_name_get)
#       101    0.000    0.000    0.000    0.000 _dtype.py:36(_kind_name)
#        12    0.000    0.000    0.000    0.000 _dtype.py:46(__str__)
#         1    0.000    0.000    0.005    0.005 _forest.py:407(_validate_X_predict)
#      1000    0.008    0.000    0.113    0.000 _forest.py:442(_accumulate_prediction)
#         1    0.000    0.000    0.336    0.336 _forest.py:631(predict_proba)
#         1    0.000    0.000    0.000    0.000 _forest.py:662(<listcomp>)
#      1001    0.005    0.000    0.034    0.000 _forest.py:667(<genexpr>)
#        92    0.000    0.000    0.000    0.000 _internal.py:830(npy_ctypes_check)
#        75    0.001    0.000    0.003    0.000 _methods.py:134(_mean)
#        75    0.002    0.000    0.004    0.000 _methods.py:167(_var)
#        14    0.000    0.000    0.000    0.000 _methods.py:28(_amax)
#        14    0.000    0.000    0.000    0.000 _methods.py:32(_amin)
#      1070    0.002    0.000    0.012    0.000 _methods.py:36(_sum)
#        15    0.000    0.000    0.000    0.000 _methods.py:44(_any)
#         7    0.000    0.000    0.000    0.000 _methods.py:47(_all)
#       150    0.000    0.000    0.001    0.000 _methods.py:50(_count_reduce_items)
#        10    0.000    0.000    0.003    0.000 _ml.py:177(begin_update)
#        10    0.000    0.000    0.001    0.000 _ml.py:212(_add_padding)
#        10    0.000    0.000    0.000    0.000 _ml.py:789(flatten)
#        10    0.000    0.000    0.000    0.000 _ml.py:792(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _parallel_backends.py:138(retrieval_context)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:201(effective_n_jobs)
#      1000    0.004    0.000    0.152    0.000 _parallel_backends.py:207(apply_async)
#      1000    0.007    0.000    0.029    0.000 _parallel_backends.py:214(get_nested_backend)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:228(effective_n_jobs)
#      1002    0.004    0.000    0.005    0.000 _parallel_backends.py:281(__init__)
#      1004    0.001    0.000    0.001    0.000 _parallel_backends.py:37(__init__)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:390(configure)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:521(effective_n_jobs)
#      1000    0.002    0.000    0.138    0.000 _parallel_backends.py:587(__init__)
#      1000    0.001    0.000    0.001    0.000 _parallel_backends.py:592(get)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:630(__init__)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:71(configure)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:81(start_call)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:84(stop_call)
#         1    0.000    0.000    0.000    0.000 _parallel_backends.py:87(terminate)
#      1001    0.001    0.000    0.001    0.000 _parallel_backends.py:90(compute_batch_size)
#      1000    0.001    0.000    0.001    0.000 _parallel_backends.py:94(batch_completed)
#        34    0.000    0.000    0.000    0.000 _ufunc_config.py:139(geterr)
#        34    0.000    0.000    0.001    0.000 _ufunc_config.py:39(seterr)
#        17    0.000    0.000    0.000    0.000 _ufunc_config.py:437(__init__)
#        17    0.000    0.000    0.000    0.000 _ufunc_config.py:441(__enter__)
#        17    0.000    0.000    0.000    0.000 _ufunc_config.py:446(__exit__)
#        36    0.000    0.000    0.000    0.000 _util.py:129(_prune_array)
#         9    0.000    0.000    0.000    0.000 _validators.py:207(validate_bool_kwarg)
#       355    0.001    0.000    0.001    0.000 _weakrefset.py:70(__contains__)
#       251    0.001    0.000    0.001    0.000 abc.py:180(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 accessor.py:183(__get__)
#         4    0.000    0.000    0.000    0.000 algorithms.py:1436(_get_take_nd_function)
#         4    0.000    0.000    0.000    0.000 algorithms.py:1565(take_nd)
#         1    0.000    0.000    0.000    0.000 api.py:107(_get_combined_index)
#         2    0.000    0.000    0.000    0.000 api.py:149(union_indexes)
#     45/15    0.000    0.000    0.009    0.001 api.py:161(begin_update)
#     45/15    0.000    0.000    0.008    0.001 api.py:163(<listcomp>)
#        45    0.000    0.000    0.000    0.000 api.py:166(<listcomp>)
#         1    0.000    0.000    0.000    0.000 api.py:221(_sanitize_and_check)
#        45    0.000    0.000    0.000    0.000 api.py:239(split_backward)
#         1    0.000    0.000    0.000    0.000 api.py:242(<setcomp>)
#        45    0.000    0.000    0.000    0.000 api.py:246(<listcomp>)
#        90    0.000    0.000    0.000    0.000 api.py:250(sink_return)
#     90/30    0.000    0.000    0.008    0.000 api.py:255(wrap)
#         1    0.000    0.000    0.000    0.000 api.py:260(get_consensus_names)
#         1    0.000    0.000    0.000    0.000 api.py:278(<setcomp>)
#        10    0.000    0.000    0.038    0.004 api.py:293(begin_update)
#        10    0.000    0.000    0.000    0.000 api.py:294(<listcomp>)
#        10    0.000    0.000    0.021    0.002 api.py:308(predict)
#        10    0.000    0.000    0.000    0.000 api.py:309(<listcomp>)
#        15    0.000    0.000    0.021    0.001 api.py:370(uniqued_fwd)
#         1    0.000    0.000    0.000    0.000 api.py:65(get_objs_combined_axis)
#         1    0.000    0.000    0.000    0.000 api.py:89(<listcomp>)
#         1    0.000    0.000    0.000    0.000 api.py:93(_get_distinct_objs)
#         5    0.000    0.000    0.000    0.000 arc_eager.pyx:547(finalize_doc)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1157(__init__)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1162(__call__)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:1489(_array_str_implementation)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:372(_get_formatdict)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:379(<lambda>)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:425(_get_format_function)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:477(wrapper)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:494(_array2string)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:532(array2string)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:69(_make_options_dict)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:715(_extendLine)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:729(_formatArray)
#       2/1    0.000    0.000    0.000    0.000 arrayprint.py:738(recurser)
#         1    0.000    0.000    0.000    0.000 arrayprint.py:74(<dictcomp>)
#        15    0.000    0.000    0.000    0.000 arraysetops.py:138(_unpack_tuple)
#        15    0.000    0.000    0.000    0.000 arraysetops.py:146(_unique_dispatcher)
#        15    0.000    0.000    0.002    0.000 arraysetops.py:151(unique)
#        15    0.001    0.000    0.002    0.000 arraysetops.py:298(_unique1d)
#         7    0.000    0.000    0.000    0.000 base.py:1035(__iter__)
#         1    0.000    0.000    0.000    0.000 base.py:108(_freeze)
#         5    0.000    0.000    0.000    0.000 base.py:113(__setattr__)
#         1    0.000    0.000    0.000    0.000 base.py:1178(_process_toarray_args)
#        46    0.000    0.000    0.000    0.000 base.py:1182(name)
#         4    0.000    0.000    0.000    0.000 base.py:1186(name)
#      1047    0.002    0.000    0.003    0.000 base.py:1192(isspmatrix)
#         3    0.000    0.000    0.000    0.000 base.py:1217(_get_names)
#         1    0.000    0.000    0.000    0.000 base.py:1220(_set_names)
#         1    0.000    0.000    0.000    0.000 base.py:1250(set_names)
#        22    0.000    0.000    0.000    0.000 base.py:1383(nlevels)
#        11    0.000    0.000    0.001    0.000 base.py:1656(is_unique)
#        20    0.000    0.000    0.000    0.000 base.py:1670(is_integer)
#         2    0.000    0.000    0.000    0.000 base.py:1679(is_object)
#         3    0.000    0.000    0.000    0.000 base.py:1730(inferred_type)
#         4    0.000    0.000    0.000    0.000 base.py:1737(is_all_dates)
#         1    0.000    0.000    0.000    0.000 base.py:2210(_validate_sort_keyword)
#        96    0.000    0.000    0.000    0.000 base.py:242(nnz)
#         1    0.000    0.000    0.000    0.000 base.py:2436(difference)
#       726    0.002    0.000    0.011    0.000 base.py:247(is_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:2581(_assert_can_do_setop)
#        82    0.000    0.000    0.003    0.000 base.py:2637(get_loc)
#     69/32    0.002    0.000    0.026    0.001 base.py:276(__new__)
#         6    0.000    0.000    0.000    0.000 base.py:2853(_convert_scalar_indexer)
#         4    0.000    0.000    0.000    0.000 base.py:294(__len__)
#         5    0.000    0.000    0.000    0.000 base.py:298(asformat)
#        46    0.000    0.000    0.000    0.000 base.py:3639(values)
#         7    0.000    0.000    0.000    0.000 base.py:3671(_values)
#         6    0.000    0.000    0.000    0.000 base.py:3701(_internal_get_values)
#        10    0.000    0.000    0.008    0.001 base.py:3810(_coerce_scalar_to_index)
#        73    0.000    0.000    0.001    0.000 base.py:3898(__contains__)
#        37    0.000    0.000    0.000    0.000 base.py:3912(__getitem__)
#         2    0.000    0.000    0.000    0.000 base.py:3950(_can_hold_identifiers_and_holds_name)
#         2    0.000    0.000    0.002    0.001 base.py:3963(append)
#         2    0.000    0.000    0.000    0.000 base.py:3987(<setcomp>)
#         2    0.000    0.000    0.002    0.001 base.py:3992(_concat)
#         2    0.000    0.000    0.002    0.001 base.py:4000(_concat_same_dtype)
#         2    0.000    0.000    0.000    0.000 base.py:4013(<listcomp>)
#         2    0.000    0.000    0.000    0.000 base.py:4020(<listcomp>)
#        23    0.000    0.000    0.001    0.000 base.py:4047(equals)
#         1    0.000    0.000    0.000    0.000 base.py:4077(identical)
#         2    0.000    0.000    0.000    0.000 base.py:4092(<genexpr>)
#        24    0.000    0.000    0.000    0.000 base.py:429(<genexpr>)
#         4    0.000    0.000    0.001    0.000 base.py:4373(get_value)
#         8    0.000    0.000    0.003    0.000 base.py:457(__mul__)
#        39    0.000    0.000    0.001    0.000 base.py:472(_simple_new)
#        14    0.000    0.000    0.000    0.000 base.py:4723(_maybe_cast_indexer)
#        10    0.000    0.000    0.016    0.002 base.py:4973(insert)
#        31    0.000    0.000    0.000    0.000 base.py:505(_get_attributes_dict)
#        31    0.000    0.000    0.000    0.000 base.py:509(<dictcomp>)
#         7    0.000    0.000    0.000    0.000 base.py:526(_shallow_copy)
#       109    0.000    0.000    0.004    0.000 base.py:5294(ensure_index)
#         4    0.000    0.000    0.000    0.000 base.py:5388(default_index)
#       116    0.000    0.000    0.001    0.000 base.py:5394(maybe_extract_name)
#        32    0.000    0.000    0.001    0.000 base.py:5410(_maybe_cast_with_dtype)
#        12    0.000    0.000    0.009    0.001 base.py:544(_shallow_copy_with_infer)
#         4    0.000    0.000    0.002    0.000 base.py:545(__rmul__)
#        22    0.000    0.000    0.001    0.000 base.py:5464(_maybe_cast_data_without_dtype)
#         3    0.000    0.000    0.000    0.000 base.py:5535(_try_convert_to_int_array)
#        23    0.000    0.000    0.000    0.000 base.py:573(is_)
#        43    0.000    0.000    0.000    0.000 base.py:592(_reset_identity)
#        17    0.000    0.000    0.001    0.000 base.py:602(_engine)
#        17    0.000    0.000    0.000    0.000 base.py:609(<lambda>)
#       237    0.000    0.000    0.001    0.000 base.py:615(__len__)
#        10    0.000    0.000    0.000    0.000 base.py:621(__array__)
#         1    0.000    0.000    0.000    0.000 base.py:635(ndim)
#        29    0.000    0.000    0.000    0.000 base.py:638(dtype)
#         4    0.000    0.000    0.000    0.000 base.py:660(view)
#         1    0.000    0.000    0.000    0.000 base.py:675(size)
#        27    0.000    0.000    0.000    0.000 base.py:677(__getattr__)
#        26    0.000    0.000    0.000    0.000 base.py:70(__init__)
#       192    0.000    0.000    0.000    0.000 base.py:84(get_shape)
#        27    0.000    0.000    0.001    0.000 base.py:862(_ndarray_values)
#         1    0.000    0.000    0.001    0.001 base.py:951(format)
#         4    0.000    0.000    0.003    0.001 base.py:955(sum)
#         1    0.000    0.000    0.001    0.001 base.py:968(_format_with_header)
#         1    0.000    0.000    0.000    0.000 base.py:980(<listcomp>)
#        89    0.001    0.000    0.002    0.000 blocks.py:118(__init__)
#        89    0.000    0.000    0.000    0.000 blocks.py:129(_check_ndim)
#         1    0.000    0.000    0.000    0.000 blocks.py:177(is_view)
#        13    0.000    0.000    0.000    0.000 blocks.py:187(is_categorical_astype)
#        16    0.000    0.000    0.000    0.000 blocks.py:202(external_values)
#         3    0.000    0.000    0.000    0.000 blocks.py:2126(should_store)
#        49    0.000    0.000    0.000    0.000 blocks.py:213(internal_values)
#         9    0.000    0.000    0.000    0.000 blocks.py:219(array_values)
#         6    0.000    0.000    0.000    0.000 blocks.py:225(get_values)
#         5    0.000    0.000    0.000    0.000 blocks.py:240(to_dense)
#       142    0.000    0.000    0.000    0.000 blocks.py:247(mgr_locs)
#        89    0.000    0.000    0.001    0.000 blocks.py:251(mgr_locs)
#        68    0.000    0.000    0.001    0.000 blocks.py:2585(__init__)
#         1    0.000    0.000    0.000    0.000 blocks.py:2591(is_bool)
#         1    0.000    0.000    0.001    0.001 blocks.py:2598(convert)
#         1    0.000    0.000    0.000    0.000 blocks.py:2613(f)
#         3    0.000    0.000    0.000    0.000 blocks.py:2646(_can_hold_element)
#         7    0.000    0.000    0.000    0.000 blocks.py:2649(should_store)
#         3    0.000    0.000    0.001    0.000 blocks.py:265(make_block)
#        42    0.000    0.000    0.001    0.000 blocks.py:275(make_block_same_class)
#        53    0.001    0.000    0.007    0.000 blocks.py:2975(get_block_type)
#         1    0.000    0.000    0.000    0.000 blocks.py:300(__len__)
#        89    0.001    0.000    0.009    0.000 blocks.py:3021(make_block)
#        18    0.000    0.000    0.000    0.000 blocks.py:3047(_extend_blocks)
#         3    0.000    0.000    0.000    0.000 blocks.py:3066(_block_shape)
#         1    0.000    0.000    0.000    0.000 blocks.py:311(_slice)
#        13    0.000    0.000    0.000    0.000 blocks.py:335(shape)
#        77    0.000    0.000    0.000    0.000 blocks.py:339(dtype)
#        12    0.000    0.000    0.000    0.000 blocks.py:343(ftype)
#        30    0.000    0.000    0.000    0.000 blocks.py:365(iget)
#        10    0.000    0.000    0.000    0.000 blocks.py:368(set)
#         1    0.000    0.000    0.000    0.000 blocks.py:385(apply)
#         1    0.000    0.000    0.001    0.001 blocks.py:445(split_and_operate)
#         1    0.000    0.000    0.000    0.000 blocks.py:467(make_a_block)
#        13    0.000    0.000    0.002    0.000 blocks.py:554(astype)
#        12    0.000    0.000    0.000    0.000 blocks.py:694(copy)
#         1    0.000    0.000    0.000    0.000 blocks.py:807(setitem)
#        24    0.000    0.000    0.000    0.000 cast.py:1097(maybe_castable)
#        23    0.000    0.000    0.001    0.000 cast.py:1111(maybe_infer_to_datetimelike)
#        32    0.000    0.000    0.003    0.000 cast.py:1218(maybe_cast_to_datetime)
#         3    0.000    0.000    0.000    0.000 cast.py:1399(cast_scalar_to_array)
#         2    0.000    0.000    0.000    0.000 cast.py:1427(construct_1d_arraylike_from_scalar)
#        21    0.000    0.000    0.000    0.000 cast.py:1467(construct_1d_object_array_from_listlike)
#        23    0.000    0.000    0.000    0.000 cast.py:1492(construct_1d_ndarray_preserving_na)
#         3    0.000    0.000    0.000    0.000 cast.py:1533(maybe_cast_to_integer_array)
#         6    0.000    0.000    0.000    0.000 cast.py:549(infer_dtype_from_scalar)
#         1    0.000    0.000    0.000    0.000 cast.py:70(maybe_convert_platform)
#         3    0.000    0.000    0.000    0.000 cast.py:799(astype_nansafe)
#         1    0.000    0.000    0.000    0.000 cast.py:951(soft_convert_objects)
#        10    0.000    0.000    0.000    0.000 catalogue.py:130(get_entry_point)
#         5    0.000    0.000    0.000    0.000 catalogue.py:144(check_exists)
#         5    0.000    0.000    0.000    0.000 catalogue.py:153(_get)
#        20    0.000    0.000    0.000    0.000 catalogue.py:160(<genexpr>)
#         5    0.000    0.000    0.000    0.000 catalogue.py:49(__contains__)
#         5    0.000    0.000    0.000    0.000 catalogue.py:85(get)
#         5    0.000    0.000    0.001    0.000 check.py:142(checked_function)
#         5    0.000    0.000    0.000    0.000 check.py:59(has_shape_inner)
#         3    0.000    0.000    0.000    0.000 common.py:1108(is_datetime_or_timedelta_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1282(needs_i8_conversion)
#         4    0.000    0.000    0.000    0.000 common.py:1369(is_string_like_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:1398(<lambda>)
#        87    0.000    0.000    0.001    0.000 common.py:1401(is_float_dtype)
#        62    0.000    0.000    0.002    0.000 common.py:1435(is_bool_dtype)
#        36    0.000    0.000    0.000    0.000 common.py:156(cast_scalar_indexer)
#       470    0.002    0.000    0.006    0.000 common.py:1565(is_extension_array_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1614(is_complex_dtype)
#        12    0.000    0.000    0.001    0.000 common.py:1647(_is_dtype)
#       106    0.000    0.000    0.001    0.000 common.py:1672(_get_dtype)
#       704    0.002    0.000    0.006    0.000 common.py:1708(_is_dtype_type)
#         1    0.000    0.000    0.000    0.000 common.py:174(not_none)
#         3    0.000    0.000    0.000    0.000 common.py:178(<genexpr>)
#         8    0.000    0.000    0.000    0.000 common.py:179(ensure_python_int)
#       246    0.001    0.000    0.001    0.000 common.py:1844(pandas_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:188(all_none)
#         8    0.000    0.000    0.000    0.000 common.py:192(<genexpr>)
#         2    0.000    0.000    0.000    0.000 common.py:195(any_not_none)
#         4    0.000    0.000    0.000    0.000 common.py:199(<genexpr>)
#       529    0.000    0.000    0.000    0.000 common.py:206(classes)
#       529    0.001    0.000    0.001    0.000 common.py:208(<lambda>)
#       175    0.000    0.000    0.000    0.000 common.py:211(classes_and_not_datetimelike)
#       175    0.000    0.000    0.000    0.000 common.py:216(<lambda>)
#       127    0.000    0.000    0.001    0.000 common.py:222(is_object_dtype)
#        66    0.000    0.000    0.002    0.000 common.py:224(asarray_tuplesafe)
#        61    0.000    0.000    0.001    0.000 common.py:252(is_sparse)
#         3    0.000    0.000    0.000    0.000 common.py:280(maybe_iterable_to_list)
#        47    0.000    0.000    0.000    0.000 common.py:335(apply_if_callable)
#        53    0.000    0.000    0.001    0.000 common.py:339(is_categorical)
#       146    0.000    0.000    0.002    0.000 common.py:372(is_datetime64_dtype)
#       191    0.000    0.000    0.003    0.000 common.py:403(is_datetime64tz_dtype)
#       165    0.000    0.000    0.002    0.000 common.py:441(is_timedelta64_dtype)
#       200    0.000    0.000    0.004    0.000 common.py:472(is_period_dtype)
#       198    0.000    0.000    0.004    0.000 common.py:506(is_interval_dtype)
#       221    0.000    0.000    0.004    0.000 common.py:542(is_categorical_dtype)
#         8    0.000    0.000    0.001    0.000 common.py:575(is_string_dtype)
#         8    0.000    0.000    0.000    0.000 common.py:605(condition)
#         7    0.000    0.000    0.000    0.000 common.py:608(is_excluded_dtype)
#        21    0.000    0.000    0.000    0.000 common.py:613(<genexpr>)
#        16    0.000    0.000    0.000    0.000 common.py:685(is_dtype_equal)
#        64    0.000    0.000    0.001    0.000 common.py:775(is_integer_dtype)
#        57    0.000    0.000    0.001    0.000 common.py:830(is_signed_integer_dtype)
#        54    0.000    0.000    0.000    0.000 common.py:887(is_unsigned_integer_dtype)
#       138    0.000    0.000    0.004    0.000 common.py:987(is_datetime64_any_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:99(is_bool_indexer)
#         1    0.000    0.000    0.000    0.000 compat.py:211(add_py3_data)
#         4    0.000    0.000    0.001    0.000 compressed.py:1009(tocoo)
#         1    0.000    0.000    0.000    0.000 compressed.py:1022(toarray)
#         1    0.000    0.000    0.000    0.000 compressed.py:1055(__get_has_canonical_format)
#         2    0.000    0.000    0.000    0.000 compressed.py:1076(__set_has_canonical_format)
#         1    0.000    0.000    0.000    0.000 compressed.py:1084(sum_duplicates)
#        72    0.000    0.000    0.000    0.000 compressed.py:110(getnnz)
#         5    0.000    0.000    0.000    0.000 compressed.py:1100(__get_sorted)
#         3    0.000    0.000    0.000    0.000 compressed.py:1115(__set_sorted)
#         5    0.000    0.000    0.000    0.000 compressed.py:1131(sort_indices)
#        18    0.000    0.000    0.001    0.000 compressed.py:1140(prune)
#         4    0.000    0.000    0.000    0.000 compressed.py:127(_set_self)
#        17    0.001    0.000    0.002    0.000 compressed.py:138(check_format)
#        17    0.000    0.000    0.003    0.000 compressed.py:30(__init__)
#         4    0.000    0.000    0.000    0.000 compressed.py:464(_mul_vector)
#         4    0.000    0.000    0.002    0.001 compressed.py:491(_mul_sparse_matrix)
#         4    0.000    0.000    0.003    0.001 compressed.py:586(sum)
#         2    0.000    0.000    0.000    0.000 concat.py:104(<genexpr>)
#         2    0.000    0.000    0.000    0.000 concat.py:105(<genexpr>)
#         2    0.000    0.000    0.000    0.000 concat.py:115(__init__)
#         3    0.000    0.000    0.000    0.000 concat.py:119(<genexpr>)
#         3    0.000    0.000    0.000    0.000 concat.py:120(<genexpr>)
#         2    0.000    0.000    0.000    0.000 concat.py:126(needs_filling)
#         2    0.000    0.000    0.000    0.000 concat.py:135(dtype)
#         2    0.000    0.000    0.000    0.000 concat.py:145(is_na)
#         2    0.000    0.000    0.000    0.000 concat.py:173(get_reindexed_values)
#         1    0.000    0.000    0.001    0.001 concat.py:236(concatenate_join_units)
#         1    0.000    0.000    0.000    0.000 concat.py:247(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:268(_get_empty_dtype_and_na)
#         2    0.000    0.000    0.000    0.000 concat.py:28(get_mgr_concatenation_plan)
#         1    0.000    0.000    0.001    0.001 concat.py:292(__init__)
#         3    0.000    0.000    0.001    0.000 concat.py:31(get_dtype_kinds)
#         1    0.000    0.000    0.000    0.000 concat.py:375(is_uniform_join_units)
#         1    0.000    0.000    0.000    0.000 concat.py:378(<listcomp>)
#         3    0.000    0.000    0.000    0.000 concat.py:384(<genexpr>)
#         2    0.000    0.000    0.000    0.000 concat.py:388(<genexpr>)
#         1    0.000    0.000    0.000    0.000 concat.py:398(_is_uniform_reindex)
#         2    0.000    0.000    0.000    0.000 concat.py:401(<genexpr>)
#         2    0.000    0.000    0.000    0.000 concat.py:434(combine_concat_plans)
#         1    0.000    0.000    0.001    0.001 concat.py:454(get_result)
#         4    0.000    0.000    0.000    0.000 concat.py:459(_next_or_none)
#         1    0.000    0.000    0.000    0.000 concat.py:507(_get_result_dim)
#         1    0.000    0.000    0.001    0.001 concat.py:513(_get_new_axes)
#         1    0.000    0.000    0.001    0.001 concat.py:516(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:520(_get_comb_axis)
#         1    0.000    0.000    0.001    0.001 concat.py:526(_get_concat_axis)
#         1    0.000    0.000    0.000    0.000 concat.py:559(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:576(_maybe_check_integrity)
#         1    0.000    0.000    0.001    0.001 concat.py:586(_concat_indexes)
#         1    0.000    0.000    0.003    0.003 concat.py:65(concat)
#         1    0.000    0.000    0.000    0.000 concat.py:72(concat_compat)
#         2    0.000    0.000    0.000    0.000 concat.py:91(is_nonempty)
#        16    0.000    0.000    0.000    0.000 config.py:101(_get_option)
#        16    0.000    0.000    0.001    0.000 config.py:230(__call__)
#        16    0.000    0.000    0.000    0.000 config.py:533(_select_options)
#        16    0.000    0.000    0.000    0.000 config.py:551(_get_root)
#        32    0.000    0.000    0.000    0.000 config.py:566(_get_deprecated_option)
#        16    0.000    0.000    0.000    0.000 config.py:594(_translate_key)
#        16    0.000    0.000    0.000    0.000 config.py:607(_warn_if_deprecated)
#        16    0.000    0.000    0.000    0.000 config.py:83(_get_single_key)
#         1    0.000    0.000    0.002    0.002 construct.py:435(hstack)
#         1    0.000    0.000    0.002    0.002 construct.py:502(bmat)
#         5    0.000    0.000    0.000    0.000 construct.py:598(<genexpr>)
#         1    0.000    0.000    0.000    0.000 construct.py:600(<listcomp>)
#         3    0.000    0.000    0.003    0.001 construction.py:123(init_ndarray)
#         3    0.000    0.000    0.017    0.006 construction.py:213(init_dict)
#         3    0.000    0.000    0.000    0.000 construction.py:245(<genexpr>)
#         2    0.000    0.000    0.000    0.000 construction.py:249(<listcomp>)
#         2    0.000    0.000    0.000    0.000 construction.py:252(<listcomp>)
#         3    0.000    0.000    0.000    0.000 construction.py:260(prep_ndarray)
#         4    0.000    0.000    0.001    0.000 construction.py:300(_homogenize)
#         3    0.000    0.000    0.002    0.001 construction.py:331(extract_index)
#        34    0.000    0.000    0.001    0.000 construction.py:337(extract_array)
#        26    0.000    0.000    0.006    0.000 construction.py:388(sanitize_array)
#         3    0.000    0.000    0.001    0.000 construction.py:417(_get_axes)
#         1    0.000    0.000    0.000    0.000 construction.py:437(to_arrays)
#         1    0.000    0.000    0.000    0.000 construction.py:488(_list_to_arrays)
#        25    0.000    0.000    0.003    0.000 construction.py:506(_try_cast)
#         4    0.000    0.000    0.006    0.002 construction.py:56(arrays_to_mgr)
#        37    0.000    0.000    0.000    0.000 construction.py:570(is_empty_data)
#         1    0.000    0.000    0.000    0.000 construction.py:574(_convert_object_array)
#         4    0.000    0.000    0.000    0.000 construction.py:586(convert)
#         1    0.000    0.000    0.001    0.001 construction.py:590(create_series_with_explicit_dtype)
#         1    0.000    0.000    0.000    0.000 construction.py:592(<listcomp>)
#         3    0.000    0.000    0.000    0.000 construction.py:601(sanitize_index)
#         1    0.000    0.000    0.000    0.000 context.py:232(get_context)
#         1    0.000    0.000    0.000    0.000 contextlib.py:157(helper)
#         1    0.000    0.000    0.000    0.000 contextlib.py:59(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:79(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:85(__exit__)
#        20    0.000    0.000    0.001    0.000 convolution.py:29(predict)
#        40    0.000    0.000    0.001    0.000 convolution.py:32(begin_update)
#        40    0.000    0.000    0.000    0.000 convolution.py:37(_get_finish_update)
#       9/5    0.000    0.000    0.001    0.000 coo.py:128(__init__)
#        24    0.000    0.000    0.000    0.000 coo.py:241(getnnz)
#         9    0.000    0.000    0.001    0.000 coo.py:267(_check)
#         1    0.000    0.000    0.000    0.000 coo.py:374(tocsr)
#         4    0.000    0.000    0.000    0.000 coo.py:596(isspmatrix_coo)
#        12    0.000    0.000    0.000    0.000 csc.py:232(_swap)
#         4    0.000    0.000    0.001    0.000 csr.py:128(transpose)
#         1    0.000    0.000    0.000    0.000 csr.py:160(tocsr)
#        59    0.000    0.000    0.000    0.000 csr.py:228(_swap)
#         1    0.000    0.000    0.000    0.000 data.py:139(split_resource_url)
#         1    0.000    0.000    0.000    0.000 data.py:166(normalize_resource_url)
#        26    0.000    0.000    0.000    0.000 data.py:22(__init__)
#         1    0.000    0.000    0.000    0.000 data.py:222(normalize_resource_name)
#        82    0.000    0.000    0.000    0.000 data.py:25(_get_dtype)
#         1    0.000    0.000    0.000    0.000 data.py:780(load)
#         8    0.000    0.000    0.000    0.000 defmatrix.py:117(__new__)
#     28/24    0.000    0.000    0.000    0.000 defmatrix.py:169(__array_finalize__)
#         4    0.000    0.000    0.000    0.000 defmatrix.py:217(__mul__)
#         4    0.000    0.000    0.000    0.000 defmatrix.py:255(_collapse)
#         4    0.000    0.000    0.000    0.000 defmatrix.py:289(sum)
#         8    0.000    0.000    0.000    0.000 defmatrix.py:38(asmatrix)
#       775    0.001    0.000    0.002    0.000 describe.py:22(__get__)
#       430    0.002    0.000    0.005    0.000 describe.py:36(__get__)
#         1    0.000    0.000    0.000    0.000 disk.py:41(memstr_to_bytes)
#        10    0.000    0.000    0.000    0.000 doc.pyx:1146(set_children_from_heads)
#         5    0.000    0.000    0.000    0.000 doc.pyx:161(__init__)
#        23    0.000    0.000    0.000    0.000 doc.pyx:301(__iter__)
#        25    0.000    0.000    0.000    0.000 doc.pyx:314(__len__)
#        18    0.000    0.000    0.000    0.000 doc.pyx:634(__pyx_fuse_0push_back)
#        15    0.000    0.000    0.000    0.000 doc.pyx:662(to_array (wrapper))
#        15    0.000    0.000    0.000    0.000 doc.pyx:662(to_array)
#         5    0.000    0.000    0.000    0.000 doc.pyx:78(_get_chunker)
#         5    0.000    0.000    0.000    0.000 doc.pyx:955(extend_tensor)
#       171    0.001    0.000    0.003    0.000 dtypes.py:1124(is_dtype)
#       490    0.002    0.000    0.003    0.000 dtypes.py:75(find)
#       173    0.000    0.000    0.003    0.000 dtypes.py:917(is_dtype)
#         9    0.000    0.000    0.000    0.000 extmath.py:681(_safe_accumulator_op)
#        15    0.000    0.000    0.001    0.000 feature_extracter.py:12(begin_update)
#        15    0.000    0.000    0.001    0.000 feature_extracter.py:14(<listcomp>)
#        15    0.000    0.000    0.001    0.000 feature_extracter.py:17(_get_feats)
#      30/5    0.000    0.000    0.019    0.004 feed_forward.py:38(predict)
#     75/15    0.001    0.000    0.045    0.003 feed_forward.py:43(begin_update)
#         1    0.000    0.000    0.000    0.000 fixes.py:200(_joblib_parallel_args)
#         1    0.000    0.000    0.001    0.001 format.py:1099(format_array)
#         1    0.000    0.000    0.000    0.000 format.py:1178(__init__)
#         1    0.000    0.000    0.001    0.001 format.py:1204(get_result)
#         1    0.000    0.000    0.001    0.001 format.py:1208(_format_strings)
#         1    0.000    0.000    0.000    0.000 format.py:1222(<lambda>)
#         1    0.000    0.000    0.000    0.000 format.py:1225(_format)
#         1    0.000    0.000    0.000    0.000 format.py:1733(_make_fixed_width)
#         2    0.000    0.000    0.000    0.000 format.py:1746(<genexpr>)
#         1    0.000    0.000    0.000    0.000 format.py:1755(just)
#         1    0.000    0.000    0.000    0.000 format.py:1761(<listcomp>)
#         1    0.000    0.000    0.000    0.000 format.py:230(__init__)
#         1    0.000    0.000    0.000    0.000 format.py:262(_chk_truncate)
#         1    0.000    0.000    0.000    0.000 format.py:293(_get_footer)
#         1    0.000    0.000    0.001    0.001 format.py:331(_get_formatted_index)
#         1    0.000    0.000    0.001    0.001 format.py:343(_get_formatted_values)
#         1    0.000    0.000    0.002    0.002 format.py:351(to_string)
#         2    0.000    0.000    0.000    0.000 format.py:393(__init__)
#         3    0.000    0.000    0.000    0.000 format.py:396(len)
#         3    0.000    0.000    0.000    0.000 format.py:399(justify)
#         1    0.000    0.000    0.000    0.000 format.py:402(adjoin)
#         2    0.000    0.000    0.000    0.000 format.py:445(_get_adjustment)
#        20    0.000    0.000    0.000    0.000 frame.py:1037(__len__)
#         1    0.000    0.000    0.001    0.001 frame.py:2595(transpose)
#        21    0.000    0.000    0.005    0.000 frame.py:2767(__getitem__)
#         9    0.000    0.000    0.001    0.000 frame.py:2885(_get_value)
#        20    0.000    0.000    0.026    0.001 frame.py:2922(__setitem__)
#        20    0.000    0.000    0.025    0.001 frame.py:2988(_set_item)
#        20    0.000    0.000    0.000    0.000 frame.py:3046(_ensure_valid_index)
#        30    0.000    0.000    0.002    0.000 frame.py:3066(_box_item_values)
#        30    0.000    0.000    0.001    0.000 frame.py:3073(_box_col_values)
#        20    0.000    0.000    0.002    0.000 frame.py:3570(_sanitize_column)
#        14    0.000    0.000    0.000    0.000 frame.py:3590(reindexer)
#         5    0.000    0.000    0.000    0.000 frame.py:399(_constructor)
#        11    0.000    0.000    0.024    0.002 frame.py:414(__init__)
#         9    0.000    0.000    0.000    0.000 frame.py:515(axes)
#         2    0.000    0.000    0.000    0.000 frame.py:532(shape)
#         1    0.000    0.000    0.000    0.000 frame.py:554(_is_homogeneous_type)
#         1    0.000    0.000    0.010    0.010 frame.py:6949(append)
#        30    0.000    0.000    0.000    0.000 fromnumeric.py:1689(_ravel_dispatcher)
#        30    0.000    0.000    0.000    0.000 fromnumeric.py:1693(ravel)
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:1800(_nonzero_dispatcher)
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:1804(nonzero)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:2087(_sum_dispatcher)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:2092(sum)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2320(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2324(all)
#        18    0.000    0.000    0.000    0.000 fromnumeric.py:2401(_cumsum_dispatcher)
#        18    0.000    0.000    0.000    0.000 fromnumeric.py:2405(cumsum)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2546(_amax_dispatcher)
#         5    0.000    0.000    0.000    0.000 fromnumeric.py:2551(amax)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2838(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2843(prod)
#        26    0.000    0.000    0.000    0.000 fromnumeric.py:3033(_ndim_dispatcher)
#        26    0.000    0.000    0.000    0.000 fromnumeric.py:3037(ndim)
#        35    0.000    0.000    0.000    0.000 fromnumeric.py:55(_wrapfunc)
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:73(_wrapreduction)
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:74(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:993(_argsort_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:997(argsort)
#         1    0.000    0.000    0.000    0.000 frozen.py:66(__getitem__)
#         3    0.000    0.000    0.000    0.000 function.py:42(__call__)
#        15    0.000    0.000    0.000    0.000 function_base.py:1137(_diff_dispatcher)
#        15    0.000    0.000    0.000    0.000 function_base.py:1141(diff)
#         1    0.000    0.000    0.000    0.000 function_base.py:257(iterable)
#        22    0.000    0.000    0.000    0.000 function_base.py:4636(_append_dispatcher)
#        22    0.000    0.000    0.001    0.000 function_base.py:4640(append)
#      1000    0.012    0.000    0.023    0.000 functools.py:44(update_wrapper)
#      1000    0.002    0.000    0.002    0.000 functools.py:74(wraps)
#      3073    0.005    0.000    0.008    0.000 generic.py:10(_check)
#         1    0.000    0.000    0.001    0.001 generic.py:1110(rename_axis)
#         1    0.000    0.000    0.001    0.001 generic.py:11145(stat_func)
#         1    0.000    0.000    0.000    0.000 generic.py:11343(logical_func)
#         1    0.000    0.000    0.001    0.001 generic.py:1281(_set_axis_name)
#         1    0.000    0.000    0.001    0.001 generic.py:1468(__invert__)
#        78    0.000    0.000    0.000    0.000 generic.py:190(__init__)
#         1    0.000    0.000    0.000    0.000 generic.py:1908(__array__)
#         4    0.000    0.000    0.000    0.000 generic.py:219(_init_mgr)
#        33    0.000    0.000    0.000    0.000 generic.py:238(attrs)
#         6    0.000    0.000    0.000    0.000 generic.py:255(_validate_dtype)
#        30    0.000    0.000    0.000    0.000 generic.py:3227(_set_as_cached)
#         2    0.000    0.000    0.000    0.000 generic.py:3255(_maybe_update_cacher)
#        24    0.000    0.000    0.000    0.000 generic.py:3294(_clear_item_cache)
#         2    0.000    0.000    0.000    0.000 generic.py:356(_construct_axes_from_arguments)
#        30    0.000    0.000    0.005    0.000 generic.py:3581(_get_item_cache)
#        20    0.000    0.000    0.023    0.001 generic.py:3623(_set_item)
#         1    0.000    0.000    0.000    0.000 generic.py:3636(_check_is_chained_assignment_possible)
#        22    0.000    0.000    0.000    0.000 generic.py:3656(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:3789(_is_view)
#         2    0.000    0.000    0.000    0.000 generic.py:381(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 generic.py:384(_from_axes)
#         6    0.000    0.000    0.000    0.000 generic.py:396(_get_axis_number)
#        12    0.000    0.000    0.000    0.000 generic.py:409(_get_axis_name)
#        11    0.000    0.000    0.000    0.000 generic.py:422(_get_axis)
#         1    0.000    0.000    0.000    0.000 generic.py:426(_get_block_manager_axis)
#         1    0.000    0.000    0.000    0.000 generic.py:4299(reindex)
#         2    0.000    0.000    0.000    0.000 generic.py:4530(<genexpr>)
#         6    0.000    0.000    0.000    0.000 generic.py:491(_info_axis)
#         5    0.000    0.000    0.000    0.000 generic.py:515(ndim)
#        34    0.000    0.000    0.001    0.000 generic.py:5235(__finalize__)
#        83    0.000    0.000    0.000    0.000 generic.py:5257(__getattr__)
#       137    0.001    0.000    0.002    0.000 generic.py:5276(__setattr__)
#         7    0.000    0.000    0.000    0.000 generic.py:5331(_protect_consolidate)
#         6    0.000    0.000    0.000    0.000 generic.py:5341(_consolidate_inplace)
#         6    0.000    0.000    0.000    0.000 generic.py:5344(f)
#         2    0.000    0.000    0.000    0.000 generic.py:5349(_consolidate)
#         1    0.000    0.000    0.000    0.000 generic.py:5371(_is_mixed_type)
#         1    0.000    0.000    0.000    0.000 generic.py:5373(<lambda>)
#         2    0.000    0.000    0.000    0.000 generic.py:5412(values)
#         4    0.000    0.000    0.003    0.001 generic.py:5519(dtypes)
#        13    0.000    0.000    0.005    0.000 generic.py:5563(astype)
#         2    0.000    0.000    0.001    0.000 generic.py:5706(copy)
#         1    0.000    0.000    0.000    0.000 generic.py:572(set_axis)
#         1    0.000    0.000    0.001    0.001 generic.py:5873(infer_objects)
#         2    0.000    0.000    0.001    0.000 generic.py:660(_set_axis)
#         1    0.000    0.000    0.001    0.001 generic.py:7264(isna)
#       112    0.000    0.000    0.000    0.000 getlimits.py:497(__init__)
#        54    0.000    0.000    0.000    0.000 getlimits.py:508(min)
#        58    0.000    0.000    0.000    0.000 getlimits.py:521(max)
#        60    0.002    0.000    0.006    0.000 hash_embed.py:56(begin_update)
#        10    0.000    0.000    0.001    0.000 index_tricks.py:318(__getitem__)
#         2    0.000    0.000    0.000    0.000 indexers.py:22(is_list_like_indexer)
#         2    0.000    0.000    0.000    0.000 indexers.py:277(check_array_indexer)
#         1    0.000    0.000    0.000    0.000 indexers.py:38(is_scalar_indexer)
#         1    0.000    0.000    0.000    0.000 indexers.py:53(is_empty_indexer)
#         1    0.000    0.000    0.000    0.000 indexers.py:79(check_setitem_lengths)
#         1    0.000    0.000    0.011    0.011 indexing.py:1067(_setitem_with_indexer_missing)
#         2    0.000    0.000    0.003    0.001 indexing.py:1659(_convert_to_indexer)
#         9    0.000    0.000    0.002    0.000 indexing.py:2168(__getitem__)
#         9    0.000    0.000    0.000    0.000 indexing.py:2200(_convert_key)
#        20    0.000    0.000    0.000    0.000 indexing.py:2260(convert_to_index_sliceable)
#         2    0.000    0.000    0.000    0.000 indexing.py:2285(check_bool_indexer)
#         2    0.000    0.000    0.000    0.000 indexing.py:230(loc)
#         2    0.000    0.000    0.000    0.000 indexing.py:2330(convert_missing_indexer)
#         1    0.000    0.000    0.000    0.000 indexing.py:2373(is_nested_tuple)
#         9    0.000    0.000    0.000    0.000 indexing.py:470(at)
#         2    0.000    0.000    0.003    0.001 indexing.py:632(_get_setitem_indexer)
#         2    0.000    0.000    0.015    0.007 indexing.py:664(__setitem__)
#         2    0.000    0.000    0.000    0.000 indexing.py:736(_convert_scalar_indexer)
#         2    0.000    0.000    0.000    0.000 indexing.py:747(_has_valid_setitem_indexer)
#         2    0.000    0.000    0.012    0.006 indexing.py:781(_setitem_with_indexer)
#         2    0.000    0.000    0.000    0.000 inference.py:220(is_array_like)
#        31    0.000    0.000    0.000    0.000 inference.py:299(is_dict_like)
#        66    0.000    0.000    0.000    0.000 inference.py:325(<genexpr>)
#         1    0.000    0.000    0.000    0.000 inference.py:331(is_named_tuple)
#       252    0.000    0.000    0.001    0.000 inference.py:358(is_hashable)
#         9    0.000    0.000    0.000    0.000 inference.py:395(is_sequence)
#        25    0.000    0.000    0.000    0.000 inference.py:96(is_iterator)
#      1023    0.002    0.000    0.003    0.000 inspect.py:73(isclass)
# ...
#         4    0.000    0.000    0.000    0.000 text.py:415(build_analyzer)
#         4    0.000    0.000    0.000    0.000 text.py:48(_preprocess)
#         8    0.000    0.000    0.000    0.000 text.py:485(_check_vocabulary)
#         4    0.000    0.000    0.000    0.000 text.py:74(_analyze)
#         9    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         9    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:215(__init__)
#      3001    0.005    0.000    0.007    0.000 threading.py:239(__enter__)
#      3001    0.005    0.000    0.007    0.000 threading.py:242(__exit__)
#      2000    0.003    0.000    0.005    0.000 threading.py:254(_is_owned)
#      2000    0.005    0.000    0.010    0.000 threading.py:334(notify)
#         9    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:74(RLock)
#        18    0.000    0.000    0.000    0.000 token.pxd:19(cinit)
#         5    0.000    0.000    0.001    0.000 tokenizer.pyx:122(__call__)
#        18    0.000    0.000    0.000    0.000 tokenizer.pyx:206(_try_cache)
#         1    0.000    0.000    0.000    0.000 treebank.py:117(tokenize)
#         3    0.000    0.000    0.000    0.000 typing.py:676(inner)
#         3    0.000    0.000    0.000    0.000 typing.py:822(__hash__)
#        35    0.000    0.000    0.000    0.000 util.py:14(<lambda>)
#        10    0.000    0.000    0.000    0.000 util.py:143(copy_array)
#        10    0.000    0.000    0.000    0.000 util.py:304(get_cuda_stream)
#         5    0.000    0.000    0.000    0.000 util.py:63(get_lang_class)
#         9    0.000    0.000    0.000    0.000 validation.py:136(_num_samples)
#         8    0.000    0.000    0.001    0.000 validation.py:252(_ensure_sparse_format)
#         9    0.000    0.000    0.000    0.000 validation.py:343(_ensure_no_complex_data)
#         9    0.000    0.000    0.006    0.001 validation.py:350(check_array)
#         9    0.000    0.000    0.001    0.000 validation.py:37(_assert_all_finite)
#       735    0.001    0.000    0.001    0.000 validation.py:474(<genexpr>)
#         8    0.000    0.000    0.000    0.000 validation.py:617(_check_large_sparse)
#      1010    0.006    0.000    0.054    0.000 validation.py:904(check_is_fitted)
#         4    0.000    0.000    0.003    0.001 validation.py:961(<listcomp>)
#      1006    0.021    0.000    0.041    0.000 validation.py:963(<listcomp>)
#         2    0.000    0.000    0.000    0.000 version.py:302(__init__)
#         2    0.000    0.000    0.000    0.000 version.py:307(parse)
#         2    0.000    0.000    0.000    0.000 version.py:312(<listcomp>)
#         1    0.000    0.000    0.000    0.000 version.py:331(_cmp)
#         1    0.000    0.000    0.000    0.000 version.py:57(__le__)
#         5    0.000    0.000    0.000    0.000 vocab.pyx:71(__get__)
#         8    0.000    0.000    0.000    0.000 warnings.py:119(filterwarnings)
#         1    0.000    0.000    0.000    0.000 warnings.py:143(simplefilter)
#         9    0.000    0.000    0.000    0.000 warnings.py:159(_add_filter)
#         9    0.000    0.000    0.000    0.000 warnings.py:428(__init__)
#         9    0.000    0.000    0.000    0.000 warnings.py:449(__enter__)
#         9    0.000    0.000    0.000    0.000 warnings.py:468(__exit__)
#        43    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x562dde7e7e00}
#        52    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.invert}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        27    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         8    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#     63/62    0.001    0.000    0.003    0.000 {built-in method builtins.all}
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        69    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.500    0.500 {built-in method builtins.exec}
# 17631/17629    0.018    0.000    0.019    0.000 {built-in method builtins.getattr}
# 3158/3136    0.005    0.000    0.009    0.000 {built-in method builtins.hasattr}
#       331    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#     12693    0.013    0.000    0.022    0.000 {built-in method builtins.isinstance}
#      2285    0.002    0.000    0.002    0.000 {built-in method builtins.issubclass}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 15105/14730    0.014    0.000    0.017    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#      1113    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#      5001    0.004    0.000    0.004    0.000 {built-in method builtins.setattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#      1006    0.001    0.000    0.001    0.000 {built-in method builtins.vars}
#        17    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
# 1142/1124    0.003    0.000    0.003    0.000 {built-in method numpy.array}
#   578/364    0.002    0.000    0.008    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        15    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#       140    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.frombuffer}
#        68    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        34    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_bool_array}
#         4    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#        31    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         4    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.get_terminal_size}
#         8    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.coo_tocsr}
#         4    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csc_matvec}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_has_canonical_format}
#         5    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_has_sorted_indices}
#         4    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_matmat_pass1}
#         4    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_matmat_pass2}
#         2    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_sort_indices}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_sum_duplicates}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_todense}
#         4    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.expandptr}
#      2004    0.003    0.000    0.003    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x7f8fbaa4ff28}
#      3001    0.002    0.000    0.002    0.000 {method '__enter__' of '_thread.lock' objects}
#      3001    0.002    0.000    0.002    0.000 {method '__exit__' of '_thread.lock' objects}
#      2009    0.002    0.000    0.002    0.000 {method 'acquire' of '_thread.lock' objects}
#        11    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         7    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        15    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#      1009    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#       535    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        16    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#        28    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        24    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        39    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        18    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#     20143    0.015    0.000    0.015    0.000 {method 'endswith' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'extend' of 'array.array' objects}
#      1011    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'fileno' of '_io.TextIOWrapper' objects}
#        28    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'findall' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'finditer' of '_sre.SRE_Pattern' objects}
#        15    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#        15    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       864    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#        93    0.000    0.000    0.003    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#        13    0.000    0.000    0.000    0.000 {method 'get_value' of 'pandas._libs.index.IndexEngine' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#      1009    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#        34    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        11    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ljust' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        14    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#        75    0.000    0.000    0.003    0.000 {method 'mean' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#        26    0.000    0.000    0.000    0.000 {method 'newbyteorder' of 'numpy.dtype' objects}
#        27    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        33    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#      1002    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#      1000    0.001    0.000    0.001    0.000 {method 'popleft' of 'collections.deque' objects}
#      1000    0.018    0.000    0.021    0.000 {method 'predict' of 'sklearn.tree._tree.Tree' objects}
#        51    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1361    0.012    0.000    0.012    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         9    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         8    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#       704    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'rjust' of 'str' objects}
#      1018    0.001    0.000    0.001    0.000 {method 'rpartition' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#         2    0.000    0.000    0.000    0.000 {method 'split' of '_sre.SRE_Pattern' objects}
#        20    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#      6037    0.004    0.000    0.004    0.000 {method 'startswith' of 'str' objects}
#        32    0.000    0.000    0.000    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#      1061    0.003    0.000    0.014    0.000 {method 'sum' of 'numpy.ndarray' objects}
#        15    0.000    0.000    0.000    0.000 {method 'to_array' of 'spacy.tokens.doc.Doc' objects}
#         2    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#      1020    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        75    0.000    0.000    0.004    0.000 {method 'var' of 'numpy.ndarray' objects}
#        61    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         4    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#        28    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#         4    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_object_object}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.array_equivalent_object}
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.clean_index_list}
#        18    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_datetimelike_array}
#        47    0.001    0.000    0.001    0.000 {pandas._libs.lib.infer_dtype}
#        15    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#        61    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#        33    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#       162    0.000    0.000    0.001    0.000 {pandas._libs.lib.is_list_like}
#       109    0.000    0.000    0.001    0.000 {pandas._libs.lib.is_scalar}
#        21    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.map_infer_mask}
#        14    0.001    0.000    0.069    0.005 {pandas._libs.lib.map_infer}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.to_object_array}
#        18    0.000    0.000    0.000    0.000 {pandas._libs.lib.values_from_object}
#         4    0.000    0.000    0.000    0.000 {sklearn.utils.sparsefuncs_fast.inplace_csr_row_normalize_l2}
